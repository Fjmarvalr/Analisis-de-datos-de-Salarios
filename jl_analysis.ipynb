# %%
import pandas as pd

# %%
df = pd.read_csv('DataScience_salaries_2025.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 93597 entries, 0 to 93596
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   work_year           93597 non-null  int64
#  1   experience_level    93597 non-null  object
#  2   employment_type     93597 non-null  object
#  3   job_title           93597 non-null  object
#  4   salary              93597 non-null  int64
#  5   salary_currency     93597 non-null  object
#  6   salary_in_usd       93597 non-null  int64
#  7   employee_residence  93597 non-null  object
#  8   remote_ratio        93597 non-null  int64
#  9   company_location    93597 non-null  object
#  10  company_size        93597 non-null  object
# dtypes: int64(4), object(7)
# memory usage: 7.9+ MB

# %%
df.head()
# Out:
#    work_year experience_level employment_type           job_title  salary  \
# 0       2025               MI              FT  Research Scientist  208000
# 1       2025               MI              FT  Research Scientist  147000
# 2       2025               SE              FT  Research Scientist  173000
# 3       2025               SE              FT  Research Scientist  117000
# 4       2025               MI              FT         AI Engineer  100000
#
#   salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0             USD         208000                 US             0
# 1             USD         147000                 US             0
# 2             USD         173000                 US             0
# 3             USD         117000                 US             0
# 4             USD         100000                 US           100
#
#   company_location company_size
# 0               US            M
# 1               US            M
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 93597 entries, 0 to 93596
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   work_year           93597 non-null  int64
#  1   experience_level    93597 non-null  object
#  2   employment_type     93597 non-null  object
#  3   job_title           93597 non-null  object
#  4   salary              93597 non-null  int64
#  5   salary_currency     93597 non-null  object
#  6   salary_in_usd       93597 non-null  int64
#  7   employee_residence  93597 non-null  object
#  8   remote_ratio        93597 non-null  int64
#  9   company_location    93597 non-null  object
#  10  company_size        93597 non-null  object
# dtypes: int64(4), object(7)
# memory usage: 7.9+ MB

# %%
df['work_year'].unique()
# Out:
# array([2025, 2024, 2022, 2023, 2020, 2021])

# %%
df12020 = df[df['work_year'] == 2020]

# %%
df12020.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 75 entries, 86261 to 93595
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   work_year           75 non-null     int64
#  1   experience_level    75 non-null     object
#  2   employment_type     75 non-null     object
#  3   job_title           75 non-null     object
#  4   salary              75 non-null     int64
#  5   salary_currency     75 non-null     object
#  6   salary_in_usd       75 non-null     int64
#  7   employee_residence  75 non-null     object
#  8   remote_ratio        75 non-null     int64
#  9   company_location    75 non-null     object
#  10  company_size        75 non-null     object
# dtypes: int64(4), object(7)
# memory usage: 7.0+ KB

# %%
df12020.head()
# Out:
#        work_year experience_level employment_type             job_title  \
# 86261       2020               EN              FT   Azure Data Engineer
# 86464       2020               EN              CT    Staff Data Analyst
# 88297       2020               SE              FT  Staff Data Scientist
# 88774       2020               EN              FT          Data Analyst
# 88806       2020               EX              FT        Data Scientist
#
#        salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 86261  100000             USD         100000                 MU             0
# 86464   60000             CAD          44753                 CA            50
# 88297  164000             USD         164000                 US            50
# 88774   42000             EUR          47899                 DE             0
# 88806  300000             USD         300000                 US           100
#
#       company_location company_size
# ...

# %%
df12020.duplicated().sum()
# Out:
# np.int64(0)

# %%
df_DS = df[df['job_title'] == 'Data Scientist']

# %%
df_DS.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 13848 entries, 14 to 93596
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   work_year           13848 non-null  int64
#  1   experience_level    13848 non-null  object
#  2   employment_type     13848 non-null  object
#  3   job_title           13848 non-null  object
#  4   salary              13848 non-null  int64
#  5   salary_currency     13848 non-null  object
#  6   salary_in_usd       13848 non-null  int64
#  7   employee_residence  13848 non-null  object
#  8   remote_ratio        13848 non-null  int64
#  9   company_location    13848 non-null  object
#  10  company_size        13848 non-null  object
# dtypes: int64(4), object(7)
# memory usage: 1.3+ MB

# %%
df_DS['salary_in_usd'].describe().round(2)
# Out:
# count     13848.00
# mean     156931.45
# std       64238.59
# min       15281.00
# 25%      110000.00
# 50%      150000.00
# 75%      192000.00
# max      750000.00
# Name: salary_in_usd, dtype: float64

# %%
df_DS_2020 = df_DS[df_DS['work_year'] == 2020]
df_DS_2020.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 25 entries, 88806 to 93594
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   work_year           25 non-null     int64
#  1   experience_level    25 non-null     object
#  2   employment_type     25 non-null     object
#  3   job_title           25 non-null     object
#  4   salary              25 non-null     int64
#  5   salary_currency     25 non-null     object
#  6   salary_in_usd       25 non-null     int64
#  7   employee_residence  25 non-null     object
#  8   remote_ratio        25 non-null     int64
#  9   company_location    25 non-null     object
#  10  company_size        25 non-null     object
# dtypes: int64(4), object(7)
# memory usage: 2.3+ KB

# %%
df_DS.groupby('work_year')['salary_in_usd'].describe().round(2)
# Out:
#             count       mean       std      min       25%       50%       75%  \
# work_year
# 2020         25.0  108943.24  98645.49  21669.0   45760.0   76958.0  118000.0
# 2021         61.0   94720.70  50681.17  16904.0   54094.0   88654.0  130000.0
# 2022        450.0  139644.64  55112.61  17684.0  104075.0  141525.0  180000.0
# 2023       1925.0  163855.09  62943.66  16000.0  125000.0  160000.0  200000.0
# 2024       8932.0  158540.63  64552.39  16666.0  110000.0  151210.0  196900.0
# 2025       2455.0  150850.98  63569.92  15281.0  110000.0  145000.0  180000.0
#
#                 max
# work_year
# 2020       412000.0
# 2021       250000.0
# 2022       350000.0
# 2023       750000.0
# 2024       750000.0
# 2025       720000.0

# %%
# Contar el numero de Data science por ano
df_DS['work_year'].value_counts()
# Out:
# work_year
# 2024    8932
# 2025    2455
# 2023    1925
# 2022     450
# 2021      61
# 2020      25
# Name: count, dtype: int64

# %%
df_DS_2020.groupby('employee_residence')['salary_in_usd'].describe().round(2)
# Out:
#                     count       mean        std       min        25%  \
# employee_residence
# AT                    1.0   91237.00        NaN   91237.0   91237.00
# DE                    3.0   63942.33   15318.76   49268.0   55997.00
# ES                    1.0   38776.00        NaN   38776.0   38776.00
# FR                    4.0   49040.00   10369.56   39916.0   41626.75
# GB                    1.0   76958.00        NaN   76958.0   76958.00
# GR                    1.0   68428.00        NaN   68428.0   68428.00
# HU                    1.0   35735.00        NaN   35735.0   35735.00
# IN                    1.0   40481.00        NaN   40481.0   40481.00
# IT                    1.0   21669.00        NaN   21669.0   21669.00
# PH                    1.0   45760.00        NaN   45760.0   45760.00
# US                   10.0  191655.00  112720.09  103000.0  108250.00
#
#                          50%        75%       max
# employee_residence
# ...

# %%
df_DS.groupby('employee_residence')['salary_in_usd'].describe().round(2)
# Out:
#                       count       mean        std       min        25%  \
# employee_residence
# AD                      1.0   50745.00        NaN   50745.0   50745.00
# AR                      5.0   42000.00   12549.90   30000.0   30000.00
# AT                     31.0   52601.48   20373.36   29706.0   34362.00
# AU                     29.0  110777.90   38004.75   52000.0   88995.00
# BE                      4.0   66790.75   13160.41   52008.0   62165.25
# BR                     11.0   73720.91   69170.93   19910.0   34000.00
# CA                    393.0  142849.97   57458.39   36000.0   98500.00
# CH                      6.0  152256.67   84237.60  104024.0  115327.50
# CL                      3.0   69346.00   65147.67   24000.0   32019.00
# CY                      1.0   63701.00        NaN   63701.0   63701.00
# DE                     52.0   91396.81   46870.15   16666.0   62570.75
# DO                      1.0  110000.00        NaN  110000.0  110000.00
# ...

# %%
df_DS_US_rest = df_DS.groupby('employee_residence')['salary_in_usd'].describe().round(2)

# %%
# Agregar una nueva columna con las diferencias entre el salario promedio de cada pais y el promedio mundial
df_DS_US_rest['mean_diff'] = df_DS_US_rest['mean'] - df_DS_US_rest['mean'].mean()

# %%
df_DS_US_rest
# Out:
#                       count       mean        std       min        25%  \
# employee_residence
# AD                      1.0   50745.00        NaN   50745.0   50745.00
# AR                      5.0   42000.00   12549.90   30000.0   30000.00
# AT                     31.0   52601.48   20373.36   29706.0   34362.00
# AU                     29.0  110777.90   38004.75   52000.0   88995.00
# BE                      4.0   66790.75   13160.41   52008.0   62165.25
# BR                     11.0   73720.91   69170.93   19910.0   34000.00
# CA                    393.0  142849.97   57458.39   36000.0   98500.00
# CH                      6.0  152256.67   84237.60  104024.0  115327.50
# CL                      3.0   69346.00   65147.67   24000.0   32019.00
# CY                      1.0   63701.00        NaN   63701.0   63701.00
# DE                     52.0   91396.81   46870.15   16666.0   62570.75
# DO                      1.0  110000.00        NaN  110000.0  110000.00
# ...
